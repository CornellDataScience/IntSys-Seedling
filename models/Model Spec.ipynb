# %%
import sys
from onnx import onnx_pb
from onnx_coreml import convert

INV_CLASS = {
    0: 'Black-grass',
    1: 'Charlock',
    2: 'Cleavers',
    3: 'Common Chickweed',
    4: 'Common wheat',
    5: 'Fat Hen',
    6: 'Loose Silky-bent',
    7: 'Maize',
    8: 'Scentless Mayweed',
    9: 'Shepherds Purse',
    10: 'Small-flowered Cranesbill',
    11: 'Sugar beet'
}
CLASSES = list(INV_CLASS.values())

model_in = "resnet/onnx/resNet_notPrune.onnx"#sys.argv[1]
model_out = "resNet_notPrune.mlmodel"#sys.argv[2]

model_file = open(model_in, 'rb')
model_proto = onnx_pb.ModelProto()
model_proto.ParseFromString(model_file.read())
coreml_model = convert(model_proto, mode='classifier', class_labels=CLASSES, image_input_names=['0']) #image_input_names=['0'], image_output_names=['186'])
coreml_model.save(model_out)

'''def convert(model,
            mode='classifier,
            image_input_names=[],
            preprocessing_args={},
            image_output_names=[],
            deprocessing_args={},
            class_labels=None,
            predicted_feature_name='classLabel',
            add_custom_layers = False,
            custom_conversion_functions = {})'''


#import coremltools
#from coremltools.models import MLModel
# Out:
# WARNING:root:TensorFlow version 1.13.1 detected. Last version known to be fully compatible is 1.12.0 .
# 1/135: Converting Node Type Conv
# 2/135: Converting Node Type BatchNormalization
# 3/135: Converting Node Type Relu
# 4/135: Converting Node Type MaxPool
# 5/135: Converting Node Type Conv
# 6/135: Converting Node Type BatchNormalization
# 7/135: Converting Node Type Relu
# 8/135: Converting Node Type Conv
# 9/135: Converting Node Type BatchNormalization
# 10/135: Converting Node Type Add
# 11/135: Converting Node Type Relu
# 12/135: Converting Node Type Conv
# 13/135: Converting Node Type BatchNormalization
# 14/135: Converting Node Type Relu
# 15/135: Converting Node Type Conv
# 16/135: Converting Node Type BatchNormalization
# 17/135: Converting Node Type Add
# 18/135: Converting Node Type Relu
# 19/135: Converting Node Type Conv
# 20/135: Converting Node Type BatchNormalization
# 21/135: Converting Node Type Relu
# 22/135: Converting Node Type Conv
# 23/135: Converting Node Type BatchNormalization
# 24/135: Converting Node Type Add
# 25/135: Converting Node Type Relu
# 26/135: Converting Node Type Conv
# 27/135: Converting Node Type BatchNormalization
# 28/135: Converting Node Type Relu
# 29/135: Converting Node Type Conv
# 30/135: Converting Node Type BatchNormalization
# 31/135: Converting Node Type Conv
# 32/135: Converting Node Type BatchNormalization
# 33/135: Converting Node Type Add
# 34/135: Converting Node Type Relu
# 35/135: Converting Node Type Conv
# 36/135: Converting Node Type BatchNormalization
# 37/135: Converting Node Type Relu
# 38/135: Converting Node Type Conv
# 39/135: Converting Node Type BatchNormalization
# 40/135: Converting Node Type Add
# 41/135: Converting Node Type Relu
# 42/135: Converting Node Type Conv
# 43/135: Converting Node Type BatchNormalization
# 44/135: Converting Node Type Relu
# 45/135: Converting Node Type Conv
# 46/135: Converting Node Type BatchNormalization
# 47/135: Converting Node Type Add
# 48/135: Converting Node Type Relu
# 49/135: Converting Node Type Conv
# 50/135: Converting Node Type BatchNormalization
# 51/135: Converting Node Type Relu
# 52/135: Converting Node Type Conv
# 53/135: Converting Node Type BatchNormalization
# 54/135: Converting Node Type Add
# 55/135: Converting Node Type Relu
# 56/135: Converting Node Type Conv
# 57/135: Converting Node Type BatchNormalization
# 58/135: Converting Node Type Relu
# 59/135: Converting Node Type Conv
# 60/135: Converting Node Type BatchNormalization
# 61/135: Converting Node Type Conv
# 62/135: Converting Node Type BatchNormalization
# 63/135: Converting Node Type Add
# 64/135: Converting Node Type Relu
# 65/135: Converting Node Type Conv
# 66/135: Converting Node Type BatchNormalization
# 67/135: Converting Node Type Relu
# 68/135: Converting Node Type Conv
# 69/135: Converting Node Type BatchNormalization
# 70/135: Converting Node Type Add
# 71/135: Converting Node Type Relu
# 72/135: Converting Node Type Conv
# 73/135: Converting Node Type BatchNormalization
# 74/135: Converting Node Type Relu
# 75/135: Converting Node Type Conv
# 76/135: Converting Node Type BatchNormalization
# 77/135: Converting Node Type Add
# 78/135: Converting Node Type Relu
# 79/135: Converting Node Type Conv
# 80/135: Converting Node Type BatchNormalization
# 81/135: Converting Node Type Relu
# 82/135: Converting Node Type Conv
# 83/135: Converting Node Type BatchNormalization
# 84/135: Converting Node Type Add
# 85/135: Converting Node Type Relu
# 86/135: Converting Node Type Conv
# 87/135: Converting Node Type BatchNormalization
# 88/135: Converting Node Type Relu
# 89/135: Converting Node Type Conv
# 90/135: Converting Node Type BatchNormalization
# 91/135: Converting Node Type Add
# 92/135: Converting Node Type Relu
# 93/135: Converting Node Type Conv
# 94/135: Converting Node Type BatchNormalization
# 95/135: Converting Node Type Relu
# 96/135: Converting Node Type Conv
# 97/135: Converting Node Type BatchNormalization
# 98/135: Converting Node Type Add
# 99/135: Converting Node Type Relu
# 100/135: Converting Node Type Conv
# 101/135: Converting Node Type BatchNormalization
# 102/135: Converting Node Type Relu
# 103/135: Converting Node Type Conv
# 104/135: Converting Node Type BatchNormalization
# 105/135: Converting Node Type Conv
# 106/135: Converting Node Type BatchNormalization
# 107/135: Converting Node Type Add
# 108/135: Converting Node Type Relu
# 109/135: Converting Node Type Conv
# 110/135: Converting Node Type BatchNormalization
# 111/135: Converting Node Type Relu
# 112/135: Converting Node Type Conv
# 113/135: Converting Node Type BatchNormalization
# 114/135: Converting Node Type Add
# 115/135: Converting Node Type Relu
# 116/135: Converting Node Type Conv
# 117/135: Converting Node Type BatchNormalization
# 118/135: Converting Node Type Relu
# 119/135: Converting Node Type Conv
# 120/135: Converting Node Type BatchNormalization
# 121/135: Converting Node Type Add
# 122/135: Converting Node Type Relu
# 123/135: Converting Node Type GlobalAveragePool
# 124/135: Converting Node Type Reshape
# 125/135: Converting Node Type Gemm
# 126/135: Converting Node Type LeakyRelu
# 127/135: Converting Node Type Unsqueeze
# 128/135: Converting Node Type BatchNormalization
# 129/135: Converting Node Type Squeeze
# 130/135: Converting Node Type Gemm
# 131/135: Converting Node Type Unsqueeze
# 132/135: Converting Node Type BatchNormalization
# 133/135: Converting Node Type Squeeze
# 134/135: Converting Node Type LeakyRelu
# 135/135: Converting Node Type LogSoftmax
# Translation to CoreML spec completed. Now compiling the CoreML model.
# Model Compilation done.
# "def convert(model,\n            mode='classifier,\n            image_input_names=[],\n            preprocessing_args={},\n            image_output_names=[],\n            deprocessing_args={},\n            class_labels=None,\n            predicted_feature_name='classLabel',\n            add_custom_layers = False,\n            custom_conversion_functions = {})"

# %%
import coremltools
from coremltools.models import MLModel

spec = coreml_model.get_spec()
new_mlmodel = MLModel(spec)
#coremltools.utils.rename_feature(spec, 'old_output_name', 'new_output_name')
#coremltools.utils.save_spec(spec, 'model_new_output_name.mlmodel')

# %%
new_mlmodel
# Out:
# input {
#   name: "0"
#   type {
#     imageType {
#       width: 128
#       height: 128
#       colorSpace: RGB
#     }
#   }
# }
# output {
#   name: "372"
#   type {
#     dictionaryType {
#       stringKeyType {
#       }
#     }
#   }
# }
# output {
#   name: "classLabel"
#   type {
#     stringType {
#     }
#   }
# }
# predictedFeatureName: "classLabel"
# predictedProbabilitiesName: "372"

# %%
coremltools.utils.rename_feature(spec, '0', 'image')
coremltools.utils.rename_feature(spec, '372', 'classLabelProbs')
MLModel(spec)
# Out:
# /Users/Brandon/anaconda3/lib/python3.6/site-packages/coremltools/models/model.py:109: RuntimeWarning: You will not be able to run predict() on this Core ML model.Underlying exception message was: Error compiling model: "Error reading protobuf spec. validator error: For this neural network classifier, the probabilities are obtained from the layer '372' which was not found in the network.".
#   RuntimeWarning)
# input {
#   name: "image"
#   type {
#     imageType {
#       width: 128
#       height: 128
#       colorSpace: RGB
#     }
#   }
# }
# output {
#   name: "classLabelProbs"
#   type {
#     dictionaryType {
#       stringKeyType {
#       }
#     }
#   }
# }
# output {
#   name: "classLabel"
#   type {
#     stringType {
#     }
#   }
# }
# predictedFeatureName: "classLabel"
# predictedProbabilitiesName: "classLabelProbs"

# %%
coremltools.utils.save_spec(spec, model_out)
